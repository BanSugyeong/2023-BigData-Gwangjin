# %% [markdown]
# ## 단독주택 공동주택 현황

# %%
import pandas as pd

df = pd.read_csv('단독_공동주택현황.csv', encoding='utf-8')
df
# Out:
#     동별(1)  동별(2)  동별(3)     2020   2020.1   2020.2   2020.3   2020.4   2020.5  \
# 0   동별(1)  동별(2)  동별(3)  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수
# 1   동별(1)  동별(2)  동별(3)       소계     단독주택     단독주택     단독주택     단독주택      아파트
# 2   동별(1)  동별(2)  동별(3)       소계       소계   일반단독주택    다가구주택   영업겸용주택       소계
# 3     서울시    광진구     소계    89832    15332      617    11711     3004    32135
# 4     서울시    광진구    화양동     5296     1413       18     1127      268     1360
# 5     서울시    광진구    군자동     4556     1435       53     1145      237      779
# 6     서울시    광진구   중곡1동     3613     1094       37      788      269      148
# 7     서울시    광진구   중곡2동     4986     1188       38      876      274      300
# 8     서울시    광진구   중곡3동     3870     1179       57      908      214      462
# 9     서울시    광진구   중곡4동     7366     1508       94     1177      237      314
# 10    서울시    광진구     능동     2531      786       44      647       95       21
# 11    서울시    광진구   구의1동     5195     1070       27      793      250      264
# 12    서울시    광진구   구의2동     7341      977       56      761      160     1355
# 13    서울시    광진구   구의3동     9070      424       15      299      110     5985
# 14    서울시    광진구    광장동    10349      214       37      117       60     9068
# 15    서울시    광진구   자양1동     5398     1205       36      893      276      784
# 16    서울시    광진구   자양2동     7066      848       14      601      233     2802
# 17    서울시    광진구   자양3동     8582      402       23      301       78     7088
# 18    서울시    광진구   자양4동     4613     1589       68     1278      243     1405
#
#      2020.6   2020.7     2020.8
# 0   종류별 주택수  종류별 주택수    종류별 주택수
# 1      연립주택    다세대주택  비거주용건물내주택
# 2        소계       소계         소계
# 3      4054    36858       1453
# 4        50     2315        158
# 5       268     1978         96
# 6        98     2159        114
# 7       100     3265        133
# 8        49     2058        122
# 9       666     4746        132
# 10       72     1620         32
# 11      180     3553        128
# 12      714     4221         74
# 13      326     2291         44
# 14      481      538         48
# 15      182     3118        109
# 16      257     3075         84
# 17      248      782         62
# 18      363     1139        117

# %%
df.columns
# Out:
# Index(['동별(1)', '동별(2)', '동별(3)', '2020', '2020.1', '2020.2', '2020.3',
#        '2020.4', '2020.5', '2020.6', '2020.7', '2020.8'],
#       dtype='object')

# %%
del df['동별(1)'], df['동별(2)']
df
# Out:
#     동별(3)     2020   2020.1   2020.2   2020.3   2020.4   2020.5   2020.6  \
# 0   동별(3)  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수  종류별 주택수
# 1   동별(3)       소계     단독주택     단독주택     단독주택     단독주택      아파트     연립주택
# 2   동별(3)       소계       소계   일반단독주택    다가구주택   영업겸용주택       소계       소계
# 3      소계    89832    15332      617    11711     3004    32135     4054
# 4     화양동     5296     1413       18     1127      268     1360       50
# 5     군자동     4556     1435       53     1145      237      779      268
# 6    중곡1동     3613     1094       37      788      269      148       98
# 7    중곡2동     4986     1188       38      876      274      300      100
# 8    중곡3동     3870     1179       57      908      214      462       49
# 9    중곡4동     7366     1508       94     1177      237      314      666
# 10     능동     2531      786       44      647       95       21       72
# 11   구의1동     5195     1070       27      793      250      264      180
# 12   구의2동     7341      977       56      761      160     1355      714
# 13   구의3동     9070      424       15      299      110     5985      326
# 14    광장동    10349      214       37      117       60     9068      481
# 15   자양1동     5398     1205       36      893      276      784      182
# 16   자양2동     7066      848       14      601      233     2802      257
# 17   자양3동     8582      402       23      301       78     7088      248
# 18   자양4동     4613     1589       68     1278      243     1405      363
#
#      2020.7     2020.8
# 0   종류별 주택수    종류별 주택수
# 1     다세대주택  비거주용건물내주택
# 2        소계         소계
# 3     36858       1453
# 4      2315        158
# 5      1978         96
# 6      2159        114
# 7      3265        133
# 8      2058        122
# 9      4746        132
# 10     1620         32
# 11     3553        128
# 12     4221         74
# 13     2291         44
# 14      538         48
# 15     3118        109
# 16     3075         84
# 17      782         62
# 18     1139        117

# %%
dong = ['화양동','군자동','중곡1동','중곡2동','중곡3동','중곡4동', '능동', '구의1동','구의2동','구의3동', '광장동', '자양1동', '자양2동', '자양3동', '자양4동']
num_house = [1413, 1435, 1094, 1188, 1179, 1508, 786, 1070, 977, 424, 214, 1205, 848, 402, 1589]
num_vacanthouse=[3883, 3121, 2519, 3798, 2691, 5858, 1745, 4125, 6364,8646, 10135, 4193, 6218, 8180, 3024]

data = pd.DataFrame(dong, columns=['행정동'])
data['단독주택'] = num_house
data['공동주택'] = num_vacanthouse

data.to_csv('행정동별주택.csv', encoding='cp949', index=False)

# %%
data1 = pd.read_csv('행정동별주택.csv', encoding='cp949', index_col=0)
data1
# Out:
#       단독주택   공동주택
# 행정동
# 화양동   1413   3883
# 군자동   1435   3121
# 중곡1동  1094   2519
# 중곡2동  1188   3798
# 중곡3동  1179   2691
# 중곡4동  1508   5858
# 능동     786   1745
# 구의1동  1070   4125
# 구의2동   977   6364
# 구의3동   424   8646
# 광장동    214  10135
# 자양1동  1205   4193
# 자양2동   848   6218
# 자양3동   402   8180
# 자양4동  1589   3024

# %%
data2 = data1.T
data2
# Out:
# 행정동    화양동   군자동  중곡1동  중곡2동  중곡3동  중곡4동    능동  구의1동  구의2동  구의3동    광장동  자양1동  \
# 단독주택  1413  1435  1094  1188  1179  1508   786  1070   977   424    214  1205
# 공동주택  3883  3121  2519  3798  2691  5858  1745  4125  6364  8646  10135  4193
#
# 행정동   자양2동  자양3동  자양4동
# 단독주택   848   402  1589
# 공동주택  6218  8180  3024

# %%
data2['구의동'] = data2['구의1동']+data2['구의2동']+data2['구의3동']
data2['자양동'] = data2['자양1동']+data2['자양2동']+data2['자양3동']+data2['자양4동']
data2['중곡동'] = data2['중곡1동']+data2['중곡2동']+data2['중곡3동']+data2['중곡4동']

del data2['구의1동'], data2['구의2동'], data2['구의3동'], data2['자양1동'], data2['자양2동'], data2['자양3동'], data2['자양4동'], data2['중곡1동'], data2['중곡2동'], data2['중곡3동'], data2['중곡4동']

data2
# Out:
# 행정동    화양동   군자동    능동    광장동    구의동    자양동    중곡동
# 단독주택  1413  1435   786    214   2471   4044   4969
# 공동주택  3883  3121  1745  10135  19135  21615  14866

# %%
data2.to_csv('법정동별주택.csv', encoding='cp949', index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

ax = data2.plot(kind='bar', title='광진구 주택현황', figsize=(9,6), legend=True, fontsize=12)
ax.set_xlabel('법정동', fontsize=12)
ax.set_ylabel('주택 수', fontsize=12)
# Out:
# Text(0, 0.5, '주택 수')
