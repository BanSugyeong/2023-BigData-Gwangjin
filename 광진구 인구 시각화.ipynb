# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %matplotlib inline

df = pd.read_csv('연도별_인구수.csv',encoding='cp949',index_col=0, thousands = ',' )
df=df.transpose()

df
# Out:
# Date       2020       2021       2022          2023          2024  \
# 광진구   4189653.0  4108883.0  4072260.0  4.018858e+06  3.958240e+06
# 화양동    268394.0   274977.0   283534.0  2.818446e+05  2.797448e+05
# 군자동    239109.0   237091.0   233985.0  2.343077e+05  2.348459e+05
# 중곡동   1014842.0   989214.0   969707.0  9.725574e+05  9.755638e+05
# 능동     139580.0   136906.0   134989.0  1.343291e+05  1.334402e+05
# 광장동    428772.0   420046.0   412689.0  4.022855e+05  3.912725e+05
# 자양동   1152240.0  1122642.0  1104253.0  1.069305e+06  1.030015e+06
# 구의동    946885.0   927954.0   933103.0  9.383792e+05  9.423171e+05
#
# Date          2025
# 광진구   3.903721e+06
# 화양동   2.776110e+05
# 군자동   2.354198e+05
# 중곡동   9.816202e+05
# 능동    1.332089e+05
# 광장동   3.800248e+05
# 자양동   9.960779e+05
# 구의동   9.497042e+05

# %%
df.to_csv('연도별_인구수.csv', encoding='cp949')

# %%
data = pd.read_csv('연도별_인구수.csv', encoding='cp949')
data
# Out:
#   Date     2020     2021     2022          2023          2024          2025
# 0  광진구  4189653  4108883  4072260  4.018858e+06  3.958240e+06  3.903721e+06
# 1  화양동   268394   274977   283534  2.818446e+05  2.797448e+05  2.776110e+05
# 2  군자동   239109   237091   233985  2.343077e+05  2.348459e+05  2.354198e+05
# 3  중곡동  1014842   989214   969707  9.725574e+05  9.755638e+05  9.816202e+05
# 4   능동   139580   136906   134989  1.343291e+05  1.334402e+05  1.332089e+05
# 5  광장동   428772   420046   412689  4.022855e+05  3.912725e+05  3.800248e+05
# 6  자양동  1152240  1122642  1104253  1.069305e+06  1.030015e+06  9.960779e+05
# 7  구의동   946885   927954   933103  9.383792e+05  9.423171e+05  9.497042e+05

# %%
del data['Date']
data
# Out:
#       2020     2021     2022          2023          2024          2025
# 0  4189653  4108883  4072260  4.018858e+06  3.958240e+06  3.903721e+06
# 1   268394   274977   283534  2.818446e+05  2.797448e+05  2.776110e+05
# 2   239109   237091   233985  2.343077e+05  2.348459e+05  2.354198e+05
# 3  1014842   989214   969707  9.725574e+05  9.755638e+05  9.816202e+05
# 4   139580   136906   134989  1.343291e+05  1.334402e+05  1.332089e+05
# 5   428772   420046   412689  4.022855e+05  3.912725e+05  3.800248e+05
# 6  1152240  1122642  1104253  1.069305e+06  1.030015e+06  9.960779e+05
# 7   946885   927954   933103  9.383792e+05  9.423171e+05  9.497042e+05

# %%
data.to_csv('법정동삭제_인구수.csv', encoding='cp949', index=False)

# %%
df1 = pd.read_csv('법정동삭제_인구수.csv', encoding='cp949')
df1
# Out:
#       2020     2021     2022          2023          2024          2025
# 0  4189653  4108883  4072260  4.018858e+06  3.958240e+06  3.903721e+06
# 1   268394   274977   283534  2.818446e+05  2.797448e+05  2.776110e+05
# 2   239109   237091   233985  2.343077e+05  2.348459e+05  2.354198e+05
# 3  1014842   989214   969707  9.725574e+05  9.755638e+05  9.816202e+05
# 4   139580   136906   134989  1.343291e+05  1.334402e+05  1.332089e+05
# 5   428772   420046   412689  4.022855e+05  3.912725e+05  3.800248e+05
# 6  1152240  1122642  1104253  1.069305e+06  1.030015e+06  9.960779e+05
# 7   946885   927954   933103  9.383792e+05  9.423171e+05  9.497042e+05

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.figure(figsize=(15,10))

x = ['2020년', '2021년', '2022년', '2023년', '2024년', '2025년']

y1=[4189653, 4108883,4072260,4018858.373,3958239.69, 3903721.086]
y2=[268394,274977,283534,281844.6361,279744.7537,277610.9995]
y3=[239109,237091,233985,234307.7318,234845.9154,235419.7977]
y4=[1014842,989214,969707,972557.4014,975563.8323,981620.2125]
y5=[139580,136906,134989,134329.1176,133440.196,133208.9176]
y6=[428772,420046,412689,402285.5042,391272.4721,380024.8498]
y7=[1152240,1122642,1104253,1069305.439,1030014.727,996077.8669]
y8=[946885,927954,933103,938379.1961,942317.1054,949704.1686]

#광진구 
plt.subplot(4, 2, 1)
plt.plot( x, y1, color='black', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("광진구 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("인구 수")

#중곡동 
plt.subplot(4, 2, 2)
plt.plot( x, y2, color='blue', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("중곡동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("인구 수")

#군자동 데이터
plt.subplot(4, 2, 3)
plt.plot( x, y3, color='orange', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("군자동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("인구 수")

#능동 데이터
plt.subplot(4, 2, 4)
plt.plot( x, y4, color='red', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("능동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("인구 수")

#구의동
plt.subplot(4, 2, 5)
plt.plot( x, y5, color='green', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("구의동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#광장동
plt.subplot(4, 2, 6)
plt.plot( x, y6, color='brown', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("광장동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#화양동
plt.subplot(4, 2, 7)
plt.plot( x, y7, color='skyblue', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("화양동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#자양동
plt.subplot(4, 2, 8)
plt.plot( x, y8, color='purple', marker='o', linestyle='solid')
plt.xticks(range(6), rotation=45)
plt.title("자양동 인구 예측 ~2026")
plt.xlabel("년/월")
plt.ylabel("단속 수")

plt.tight_layout()
plt.show()
