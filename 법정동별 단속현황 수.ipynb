# %% [markdown]
# ## 법정동별 단속현황 수

# %%
import pandas as pd

dong = ['중곡동', '군자동', '능동', '구의동', '광장동', '화양동', '자양동']
df2201 = [227, 49, 218, 402, 241, 117, 402]
df2202 = [284, 91, 268, 331, 195, 106, 307]
df2203 = [266, 91, 326, 329, 212, 103, 334]
df2204 = [293, 78, 580, 321, 365, 195, 386]
df2205 = [269, 75, 375, 308, 298, 158, 400]
df2206 = [77, 11, 87, 111, 55, 20, 54]
df2207 = [56, 8, 88, 110, 23, 17, 95]
df2208 = [17, 6, 56, 138, 24, 9, 56]
df2209 = [5, 1, 53, 64, 3, 0, 54]
df2210 = [4, 1, 55, 75, 14, 0, 33]
df2211 = [2, 3, 43, 76, 10, 2, 53]
df2212 = [11, 1, 69, 84, 0, 5, 35]
df2301 = [263, 20, 98, 138, 30, 12, 102]
df2302 = [194, 14, 54, 108, 23, 12, 103]

data = pd.DataFrame(dong, columns=['법정동'])
data['2201'] = df2201
data['2202'] = df2202
data['2203'] = df2203
data['2204'] = df2204
data['2205'] = df2205
data['2206'] = df2206
data['2207'] = df2207
data['2208'] = df2208
data['2209'] = df2209
data['2210'] = df2210
data['2211'] = df2211
data['2212'] = df2212
data['2301'] = df2301
data['2302'] = df2302


data
# Out:
#    법정동  2201  2202  2203  2204  2205  2206  2207  2208  2209  2210  2211  \
# 0  중곡동   227   284   266   293   269    77    56    17     5     4     2
# 1  군자동    49    91    91    78    75    11     8     6     1     1     3
# 2   능동   218   268   326   580   375    87    88    56    53    55    43
# 3  구의동   402   331   329   321   308   111   110   138    64    75    76
# 4  광장동   241   195   212   365   298    55    23    24     3    14    10
# 5  화양동   117   106   103   195   158    20    17     9     0     0     2
# 6  자양동   402   307   334   386   400    54    95    56    54    33    53
#
#    2212  2301  2302
# 0    11   263   194
# 1     1    20    14
# 2    69    98    54
# 3    84   138   108
# 4     0    30    23
# 5     5    12    12
# 6    35   102   103

# %%
data.to_csv('법정도별_단속현황수.csv', index=False, encoding='cp949')

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
jungkok = data[0:1]
jungkok
# Out:
#    법정동  2201  2202  2203  2204  2205  2206  2207  2208  2209  2210  2211  \
# 0  중곡동   227   284   266   293   269    77    56    17     5     4     2
#
#    2212  2301  2302
# 0    11   263   194

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

year = ['22년 1월','22년 2월','22년 3월','22년 4월','22년 5월','22년 6월','22년 7월','22년 8월','22년 9월','22년 10월','22년 11월','22년 12월','23년 1월','23년 2월']
crackdown_dong1 = [227,284,266,293,269,77,56,17,5,4,2,11,263,194] 

plt.plot( year, crackdown_dong1, color='green', marker='o', label='중곡동')
plt.xticks(range(14), rotation=45)
plt.title("중곡동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")
plt.show()

# %%
plt.figure(figsize=(15,10))

x= ['22년 1월','22년 2월','22년 3월','22년 4월','22년 5월','22년 6월','22년 7월','22년 8월','22년 9월','22년 10월','22년 11월','22년 12월','23년 1월','23년 2월']
y1 = [227, 284, 266, 293, 269, 77, 56, 17, 5, 4, 2, 11, 263, 194]  #중곡동
y2 = [49, 91, 91, 78, 75, 11, 8, 6, 1, 1, 3, 1, 20, 14] #군자동
y3 = [218, 268, 326, 580, 375, 87, 88, 56, 53, 55, 43, 69, 98, 54] #능동
y4 = [402, 331, 329, 321, 308, 111, 110, 138, 64, 75, 76, 84, 138, 108] #구의동
y5 = [241, 195, 212, 365, 298, 55, 23, 24, 3, 14, 10, 0, 30, 23] #광장동
y6 = [117, 106, 103, 195, 158, 20, 17, 9, 0, 0, 2, 5, 12, 12] #화양동
y7 = [402, 307, 334, 386, 400, 54, 95, 56, 54, 33, 53, 35, 102, 103] #자양동

#중곡동 데이터
plt.subplot(4, 2, 1)
plt.plot( x, y1, color='blue', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("중곡동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#군자동 데이터
plt.subplot(4, 2, 2)
plt.plot( x, y2, color='orange', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("군자동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#능동 데이터
plt.subplot(4, 2, 3)
plt.plot( x, y3, color='red', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("능동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#구의동
plt.subplot(4, 2, 4)
plt.plot( x, y4, color='green', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("구의동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#광장동
plt.subplot(4, 2, 5)
plt.plot( x, y5, color='brown', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("광장동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#화양동
plt.subplot(4, 2, 6)
plt.plot( x, y6, color='pink', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("화양동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

#자양동
plt.subplot(4, 2, 7)
plt.plot( x, y7, color='purple', marker='o', linestyle='solid')
plt.xticks(range(14), rotation=45)
plt.title("자양동 단속현황")
plt.xlabel("년/월")
plt.ylabel("단속 수")

plt.tight_layout()
plt.show()
